# %% [markdown]
# <a href="https://colab.research.google.com/github/maverick2903/Kernel_Krushers_DataHack1.0/blob/main/DataHack_FinBERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 48.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.7)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 77.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.3 tokenizers-0.13.2 transformers-4.27.4

# %%
from bs4 import BeautifulSoup
import requests
import time

# %%
bank_name = "hdfc"
search_url = f"https://www.google.com/search?q={bank_name}&sxsrf=APwXEdfVzpfAF54BQQ6e0mr5fI2tPeW97A:1680341954287&source=lnms&tbm=nws&sa=X&ved=2ahUKEwie8KTKsYj-AhWkU2wGHatNBAkQ_AUoAnoECAEQBA&biw=1536&bih=754&dpr=1.25"
headers = {
  "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36 Edge/16.16299"
}
response = requests.get(search_url, headers=headers)
soup = BeautifulSoup(response.content, "lxml")
article_links = []
links = soup.find_all("a")
for tag in links:
    href = tag.get("href")
    if href.startswith('/url?esrc=s&q=&rct=j&sa=U&url=')==True:
      index = href.find("&ved=")
      if index != -1:
          href = href[:index] 
      article_links.append(href[30::])


article_data = []

for link in article_links:
  response_ = requests.get(link, headers=headers)
  soup_ = BeautifulSoup(response_.content, "lxml")
  meta_tag = soup_.find('meta', attrs={'name': 'description'})
  if meta_tag:
    description = meta_tag.get('content')
    article_data.append(description)
    print(description)
  else:
    print("No meta tag found for link:", link)


# if __name__ == '__main__':
#     while True:
#         find_data()
#         time.sleep(600)
# Out:
# In her book "Adityanama", Anita Puri,  whom he calls "Smiley", provides readers with insights into her husband's life. Here are six anecdotes, drawn from her book.
# Buy or sell stocks: Anuj Gupta of IIFL Securities has recommended five stocks to buy on Monday —HDFC Bank, ICICI Bank, JSW Steel, Federal Bank and BEL
# Markets News: MUMBAI: Equity benchmark indices climbed in early trade on Tuesday tracking a firm trend in Asian markets and buying in index major Reliance Industrie.
# Indian equity benchmarks started Wednesday's session on a positive note with mild gains amid mixed moves across global markets as a deal between First Citizens Bank Shares and Silicon Valley Bank (SVB). Get more Stocks News and Business News on Zee Business.
# Veriti Management LLC increased its position in shares of  HDFC Bank Limited (NYSE:HDB - Get Rating) by 72.5% during the 4th quarter, according to the company in its most recent 13F filing with the Securities and Exchange Commission. The institutional investor  owned 11,701 shares of the bank's stoc
# Shares of HDFC Bank Ltd. rose 1.34% to 1,609.75 Indian rupees Friday, on what proved to be an all-around great trading session for the stock market, with the...
# HDFC Bank can finance up to 100% of the “on-road price” on select new cars, electric vehicles, as well as used cars. Here’s a list of their interest rates.
# The largest private sector lender HDFC Bank has revised its interest rates on non-withdrawable fixed deposits (FDs).
# The board also approved increase in borrowing powers of HDFC to Rs 6.5 lakh crore from Rs 6 lakh crore
# HDFC Bank opened its first branch in the state in 1995, at Anna Salai here. "It is a privilege to be touching this landmark (500 branches) in the state. We are committed to helping the people of Tamil Nadu progress further through our world class products and services backed by a strong culture of service," Kumar said.

# %%
from transformers import BertTokenizer , BertForSequenceClassification
from transformers import pipeline

# %%
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone',num_labels=3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/533 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %%
nlp = pipeline("sentiment-analysis",model=finbert,tokenizer=tokenizer)

# %%
sentence = article_data

# %%
results = nlp(sentence)
print(results)
# Out:
# [{'label': 'Neutral', 'score': 0.9999822378158569}, {'label': 'Neutral', 'score': 0.9999972581863403}, {'label': 'Positive', 'score': 0.9924736022949219}, {'label': 'Neutral', 'score': 0.9994663596153259}, {'label': 'Positive', 'score': 0.9999984502792358}, {'label': 'Neutral', 'score': 0.9997852444648743}, {'label': 'Positive', 'score': 0.9855802059173584}, {'label': 'Positive', 'score': 0.7813543081283569}, {'label': 'Neutral', 'score': 0.9999915361404419}, {'label': 'Neutral', 'score': 0.9999986886978149}]

# %%
import yfinance as yf
msft = yf.Ticker("MSFT")
hist = msft.history(period="1mo")
print(hist)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 